# %% [markdown]
# <a href="https://colab.research.google.com/github/ThaGeekiestOne/Deeplearning-practice/blob/main/winequality.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
3
# Out:
# 3
